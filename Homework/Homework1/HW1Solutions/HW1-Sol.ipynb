# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def gaussian1d(x, mu, sigma):
    """
    1-D Gaussian
    """
    return 1.0/((2*np.pi)**0.5 * sigma**0.5) * np.exp(-(x-mu)**2 / (2 * sigma**2))

# %% [markdown]
# ### Problem 1(2)a

# %%
""" Label the testing sample assuming equal prior probability
"""
xtest = 4.7

for mu, sigma in [(4, 2), (6, 3), (5, 2)]:
    print(gaussian(xtest, mu, sigma))
# Out:
# 0.24957092803615238
# 0.15095935093123042
# 0.2758185316627059

# %% [markdown]
# ### Plot  the three pdf's

# %%
xtest = np.arange(-10, 15, 0.1)

for mu, sigma in [(4, 2), (6, 3), (5, 2)]:
    plt.plot(xtest, gaussian1d(xtest, mu, sigma))

plt.show()
